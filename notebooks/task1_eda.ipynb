# %%
import sys
import os
import sys
print(sys.executable)

# Add src/ to the path so we can import our modules from the notebook
sys.path.append(os.path.abspath(os.path.join("..", "src")))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make plots render inline and look a bit nicer
# %matplotlib inline
plt.style.use("seaborn-v0_8-darkgrid")

from data_loader import fetch_data
from data_cleaning import check_missing_values, check_basic_stats, handle_missing_values
# Out:
# c:\Users\HP\fraud-detection\.venv\Scripts\python.exe
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      13 # Make plots render inline and look a bit nicer
#      14 get_ipython().run_line_magic('matplotlib', 'inline')
#      15 plt.style.use("seaborn-v0_8-darkgrid")
#      16
# ---> 17 from data_loader import fetch_data
#      18 from data_cleaning import check_missing_values, check_basic_stats, handle_missing_values
#
# File c:\Users\HP\portfolio-optimization\src\data_loader.py:1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#       3 import time
#
# ModuleNotFoundError: No module named 'yfinance'
